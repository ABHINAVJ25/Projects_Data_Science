# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %% [markdown]
# Question 1: Import the dataset.

# %%
df = pd.read_csv("hospitalisations.csv")

# %% [markdown]
# Question 2: How many rows and columns does the data set have?

# %%
df
# Out:
#                        State/UT    Private     Public
# 0   Andaman and Nicobar Islands        1.0       21.0
# 1                Andhra Pradesh    97863.0    34385.0
# 2             Arunachal Pradesh        5.0      630.0
# 3                         Assam    14350.0    33553.0
# 4                         Bihar    11747.0    34814.0
# 5                    Chandigarh      302.0      509.0
# 6                  Chhattisgarh   411814.0   142123.0
# 7        Dadra and Nagar Haveli      782.0    10940.0
# 8                 Daman and Diu      984.0     3343.0
# 9                           Goa     1033.0      382.0
# 10                      Gujarat   379379.0    94845.0
# 11                      Haryana    16341.0    10223.0
# 12             Himachal Pradesh     2160.0    16461.0
# 13            Jammu and Kashmir     9707.0     8720.0
# 14                    Jharkhand   156760.0    24114.0
# 15                    Karnataka    65502.0   128640.0
# 16                       Kerala   131557.0   391079.0
# 17                  Lakshadweep        NaN        NaN
# 18               Madhya Pradesh    29314.0    63818.0
# 19                  Maharashtra   107977.0    31179.0
# 20                      Manipur      725.0     2412.0
# 21                    Meghalaya     4836.0     9016.0
# 22                      Mizoram      441.0    12588.0
# 23                     Nagaland      325.0      532.0
# 24                   Puducherry        NaN        NaN
# 25                       Sikkim       21.0       91.0
# 26                   Tamil Nadu   120473.0   116701.0
# 27                      Tripura       90.0    16702.0
# 28                Uttar Pradesh    89987.0    26800.0
# 29                  Uttarakhand    30472.0    18108.0
# 30                  West Bengal    12169.0     5467.0
# 31                  Grand Total  1697117.0  1238196.0

# %%
len(df)
# Out:
# 32

# %% [markdown]
# Question 3: Does the data set have missing values? If yes, how many?
#
# Ans use i. data_set.isnull() method,
#         ii. data_set.isna()
#         iii. data_set.isna().sum().sum()

# %%
df.isnull()
# Out:
#     State/UT  Private  Public
# 0      False    False   False
# 1      False    False   False
# 2      False    False   False
# 3      False    False   False
# 4      False    False   False
# 5      False    False   False
# 6      False    False   False
# 7      False    False   False
# 8      False    False   False
# 9      False    False   False
# 10     False    False   False
# 11     False    False   False
# 12     False    False   False
# 13     False    False   False
# 14     False    False   False
# 15     False    False   False
# 16     False    False   False
# 17     False     True    True
# 18     False    False   False
# 19     False    False   False
# 20     False    False   False
# 21     False    False   False
# 22     False    False   False
# 23     False    False   False
# 24     False     True    True
# 25     False    False   False
# 26     False    False   False
# 27     False    False   False
# 28     False    False   False
# 29     False    False   False
# 30     False    False   False
# 31     False    False   False

# %%
null_v = df.isna().sum().sum()
null_v
# Out:
# 4

# %%
df.isna().sum()
# Out:
# State/UT    0
# Private     2
# Public      2
# dtype: int64

# %% [markdown]
# Question 4: Drop the NA values.

# %%
df.drop(null_v)
# Out:
#                        State/UT    Private     Public
# 0   Andaman and Nicobar Islands        1.0       21.0
# 1                Andhra Pradesh    97863.0    34385.0
# 2             Arunachal Pradesh        5.0      630.0
# 3                         Assam    14350.0    33553.0
# 5                    Chandigarh      302.0      509.0
# 6                  Chhattisgarh   411814.0   142123.0
# 7        Dadra and Nagar Haveli      782.0    10940.0
# 8                 Daman and Diu      984.0     3343.0
# 9                           Goa     1033.0      382.0
# 10                      Gujarat   379379.0    94845.0
# 11                      Haryana    16341.0    10223.0
# 12             Himachal Pradesh     2160.0    16461.0
# 13            Jammu and Kashmir     9707.0     8720.0
# 14                    Jharkhand   156760.0    24114.0
# 15                    Karnataka    65502.0   128640.0
# 16                       Kerala   131557.0   391079.0
# 17                  Lakshadweep        NaN        NaN
# 18               Madhya Pradesh    29314.0    63818.0
# 19                  Maharashtra   107977.0    31179.0
# 20                      Manipur      725.0     2412.0
# 21                    Meghalaya     4836.0     9016.0
# 22                      Mizoram      441.0    12588.0
# 23                     Nagaland      325.0      532.0
# 24                   Puducherry        NaN        NaN
# 25                       Sikkim       21.0       91.0
# 26                   Tamil Nadu   120473.0   116701.0
# 27                      Tripura       90.0    16702.0
# 28                Uttar Pradesh    89987.0    26800.0
# 29                  Uttarakhand    30472.0    18108.0
# 30                  West Bengal    12169.0     5467.0
# 31                  Grand Total  1697117.0  1238196.0

# %%
df.dropna()
# Out:
#                        State/UT    Private     Public
# 0   Andaman and Nicobar Islands        1.0       21.0
# 1                Andhra Pradesh    97863.0    34385.0
# 2             Arunachal Pradesh        5.0      630.0
# 3                         Assam    14350.0    33553.0
# 4                         Bihar    11747.0    34814.0
# 5                    Chandigarh      302.0      509.0
# 6                  Chhattisgarh   411814.0   142123.0
# 7        Dadra and Nagar Haveli      782.0    10940.0
# 8                 Daman and Diu      984.0     3343.0
# 9                           Goa     1033.0      382.0
# 10                      Gujarat   379379.0    94845.0
# 11                      Haryana    16341.0    10223.0
# 12             Himachal Pradesh     2160.0    16461.0
# 13            Jammu and Kashmir     9707.0     8720.0
# 14                    Jharkhand   156760.0    24114.0
# 15                    Karnataka    65502.0   128640.0
# 16                       Kerala   131557.0   391079.0
# 18               Madhya Pradesh    29314.0    63818.0
# 19                  Maharashtra   107977.0    31179.0
# 20                      Manipur      725.0     2412.0
# 21                    Meghalaya     4836.0     9016.0
# 22                      Mizoram      441.0    12588.0
# 23                     Nagaland      325.0      532.0
# 25                       Sikkim       21.0       91.0
# 26                   Tamil Nadu   120473.0   116701.0
# 27                      Tripura       90.0    16702.0
# 28                Uttar Pradesh    89987.0    26800.0
# 29                  Uttarakhand    30472.0    18108.0
# 30                  West Bengal    12169.0     5467.0
# 31                  Grand Total  1697117.0  1238196.0

# %% [markdown]
# Question 5: Create a new column Total which contains a sum of private and public
# hospitalisations. So the column Total should be a summation of the two columns
# Public and Private.

# %%
# adding column total to the data frame 
# print(df(Private + Public))
# print(df["Private"])
# total = df["Private"] + df["Public"]
# total

df['Total'] = df["Private"] + df["Public"]

# %%
df
# Out:
#                        State/UT    Private     Public      Total
# 0   Andaman and Nicobar Islands        1.0       21.0       22.0
# 1                Andhra Pradesh    97863.0    34385.0   132248.0
# 2             Arunachal Pradesh        5.0      630.0      635.0
# 3                         Assam    14350.0    33553.0    47903.0
# 4                         Bihar    11747.0    34814.0    46561.0
# 5                    Chandigarh      302.0      509.0      811.0
# 6                  Chhattisgarh   411814.0   142123.0   553937.0
# 7        Dadra and Nagar Haveli      782.0    10940.0    11722.0
# 8                 Daman and Diu      984.0     3343.0     4327.0
# 9                           Goa     1033.0      382.0     1415.0
# 10                      Gujarat   379379.0    94845.0   474224.0
# 11                      Haryana    16341.0    10223.0    26564.0
# 12             Himachal Pradesh     2160.0    16461.0    18621.0
# 13            Jammu and Kashmir     9707.0     8720.0    18427.0
# 14                    Jharkhand   156760.0    24114.0   180874.0
# 15                    Karnataka    65502.0   128640.0   194142.0
# 16                       Kerala   131557.0   391079.0   522636.0
# 17                  Lakshadweep        NaN        NaN        NaN
# 18               Madhya Pradesh    29314.0    63818.0    93132.0
# 19                  Maharashtra   107977.0    31179.0   139156.0
# 20                      Manipur      725.0     2412.0     3137.0
# 21                    Meghalaya     4836.0     9016.0    13852.0
# 22                      Mizoram      441.0    12588.0    13029.0
# 23                     Nagaland      325.0      532.0      857.0
# 24                   Puducherry        NaN        NaN        NaN
# 25                       Sikkim       21.0       91.0      112.0
# 26                   Tamil Nadu   120473.0   116701.0   237174.0
# 27                      Tripura       90.0    16702.0    16792.0
# 28                Uttar Pradesh    89987.0    26800.0   116787.0
# 29                  Uttarakhand    30472.0    18108.0    48580.0
# 30                  West Bengal    12169.0     5467.0    17636.0
# 31                  Grand Total  1697117.0  1238196.0  2935313.0

# %%
# df.drop("total", axis = 1, inplace = True)

# %% [markdown]
# Question 6: Which State or UT is the unhealthiest? (i.e. maximum number of hospitalisations)
#
#             HINT : Do not include Grand Total

# %%
df1 = df.drop(31, axis = 0)

# %%
df2 = df.dropna(inplace = True)

# %%
max_no_of_h = np.max(df1)
max_no_of_h
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# State/UT    West Bengal
# Private        411814.0
# Public         391079.0
# Total          553937.0
# dtype: object

# %% [markdown]
# Question 7: Chhattisgarh accounts for roughly 18% share in the total hospitalisations in India
#
# (assuming these are the only states/UTs in India). True for False?
#
# Ans - true

# %%
plt.pie(df["Total"], labels = df["State/UT"], autopct = "%0.1f%%");

# %% [markdown]
# Question 8: In Dadra and Nagar Haveli, which type of hospitals do people prefer?
#
#     Ans:  df[df["State/UT"] == "Dadra and Nagar Haveli" ]

# %%
# df = df.astype(int)
print(df.loc[7])
# Out:
# State/UT    Dadra and Nagar Haveli
# Private                      782.0
# Public                     10940.0
# Total                      11722.0
# Name: 7, dtype: object

# %%
df[df["State/UT"] == "Dadra and Nagar Haveli" ]
# Out:
#                  State/UT  Private   Public    Total
# 7  Dadra and Nagar Haveli    782.0  10940.0  11722.0

# %% [markdown]
# Question 9: Plot the total hospitalisations in a plot of your choice and comment on the
# healthiest State/UT.
#
# (Assuming that the only parameter for Healthiest is the number of
# hospitalisations only)

# %%
df
# Out:
#                        State/UT    Private     Public      Total
# 0   Andaman and Nicobar Islands        1.0       21.0       22.0
# 1                Andhra Pradesh    97863.0    34385.0   132248.0
# 2             Arunachal Pradesh        5.0      630.0      635.0
# 3                         Assam    14350.0    33553.0    47903.0
# 4                         Bihar    11747.0    34814.0    46561.0
# 5                    Chandigarh      302.0      509.0      811.0
# 6                  Chhattisgarh   411814.0   142123.0   553937.0
# 7        Dadra and Nagar Haveli      782.0    10940.0    11722.0
# 8                 Daman and Diu      984.0     3343.0     4327.0
# 9                           Goa     1033.0      382.0     1415.0
# 10                      Gujarat   379379.0    94845.0   474224.0
# 11                      Haryana    16341.0    10223.0    26564.0
# 12             Himachal Pradesh     2160.0    16461.0    18621.0
# 13            Jammu and Kashmir     9707.0     8720.0    18427.0
# 14                    Jharkhand   156760.0    24114.0   180874.0
# 15                    Karnataka    65502.0   128640.0   194142.0
# 16                       Kerala   131557.0   391079.0   522636.0
# 18               Madhya Pradesh    29314.0    63818.0    93132.0
# 19                  Maharashtra   107977.0    31179.0   139156.0
# 20                      Manipur      725.0     2412.0     3137.0
# 21                    Meghalaya     4836.0     9016.0    13852.0
# 22                      Mizoram      441.0    12588.0    13029.0
# 23                     Nagaland      325.0      532.0      857.0
# 25                       Sikkim       21.0       91.0      112.0
# 26                   Tamil Nadu   120473.0   116701.0   237174.0
# 27                      Tripura       90.0    16702.0    16792.0
# 28                Uttar Pradesh    89987.0    26800.0   116787.0
# 29                  Uttarakhand    30472.0    18108.0    48580.0
# 30                  West Bengal    12169.0     5467.0    17636.0
# 31                  Grand Total  1697117.0  1238196.0  2935313.0

# %%
sns.catplot(x= "Total", y = "State/UT", kind = "bar", data = df.sort_values(by = "Total", ascending = True), height = 5);
plt.show()

# %%
sns.catplot(x= "Total", y = "State/UT", kind = "bar", data = df1.sort_values(by = "Total", ascending = True), height = 5);
plt.show()

# %%
finding_healthy=df1.groupby(['State/UT']).sum()['Total'].sort_values()
finding_healthy.index
# Out:
# Index(['Puducherry', 'Lakshadweep', 'Andaman and Nicobar Islands', 'Sikkim',
#        'Arunachal Pradesh', 'Chandigarh', 'Nagaland', 'Goa', 'Manipur',
#        'Daman and Diu', 'Dadra and Nagar Haveli', 'Mizoram', 'Meghalaya',
#        'Tripura', 'West Bengal', 'Jammu and Kashmir', 'Himachal Pradesh',
#        'Haryana', 'Bihar', 'Assam', 'Uttarakhand', 'Madhya Pradesh',
#        'Uttar Pradesh', 'Andhra Pradesh', 'Maharashtra', 'Jharkhand',
#        'Karnataka', 'Tamil Nadu', 'Gujarat', 'Kerala', 'Chhattisgarh'],
#       dtype='object', name='State/UT')

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=finding_healthy.values, y=finding_healthy.index)
plt.xscale('log')

# %% [markdown]
# Question 10: Public Hospitalisations are more on an all India level as compared to state/UT level. True or False?
#
# HINT: Calculate the percentage of public hospitalisation (public/total), then find out the average percentage of all states using the mean() function. Compare this average percentage (state) with the grand total (all India) percentage and comment.
#
# HINT: Calculate the percentage of public hospitalisation (public/total), then find out the average percentage of all states using the mean() function. Compare this average percentage with the grand total percentage and comment.

# %%
df["pub_per"] = df['Public'] / df['Total']

# %%
df
# Out:
#                        State/UT    Private     Public      Total   pub_per
# 0   Andaman and Nicobar Islands        1.0       21.0       22.0  0.954545
# 1                Andhra Pradesh    97863.0    34385.0   132248.0  0.260004
# 2             Arunachal Pradesh        5.0      630.0      635.0  0.992126
# 3                         Assam    14350.0    33553.0    47903.0  0.700436
# 4                         Bihar    11747.0    34814.0    46561.0  0.747707
# 5                    Chandigarh      302.0      509.0      811.0  0.627620
# 6                  Chhattisgarh   411814.0   142123.0   553937.0  0.256569
# 7        Dadra and Nagar Haveli      782.0    10940.0    11722.0  0.933288
# 8                 Daman and Diu      984.0     3343.0     4327.0  0.772591
# 9                           Goa     1033.0      382.0     1415.0  0.269965
# 10                      Gujarat   379379.0    94845.0   474224.0  0.200000
# 11                      Haryana    16341.0    10223.0    26564.0  0.384844
# 12             Himachal Pradesh     2160.0    16461.0    18621.0  0.884002
# 13            Jammu and Kashmir     9707.0     8720.0    18427.0  0.473219
# 14                    Jharkhand   156760.0    24114.0   180874.0  0.133319
# 15                    Karnataka    65502.0   128640.0   194142.0  0.662608
# 16                       Kerala   131557.0   391079.0   522636.0  0.748282
# 18               Madhya Pradesh    29314.0    63818.0    93132.0  0.685242
# 19                  Maharashtra   107977.0    31179.0   139156.0  0.224058
# 20                      Manipur      725.0     2412.0     3137.0  0.768887
# 21                    Meghalaya     4836.0     9016.0    13852.0  0.650881
# 22                      Mizoram      441.0    12588.0    13029.0  0.966152
# 23                     Nagaland      325.0      532.0      857.0  0.620770
# 25                       Sikkim       21.0       91.0      112.0  0.812500
# 26                   Tamil Nadu   120473.0   116701.0   237174.0  0.492048
# 27                      Tripura       90.0    16702.0    16792.0  0.994640
# 28                Uttar Pradesh    89987.0    26800.0   116787.0  0.229478
# 29                  Uttarakhand    30472.0    18108.0    48580.0  0.372746
# 30                  West Bengal    12169.0     5467.0    17636.0  0.309991
# 31                  Grand Total  1697117.0  1238196.0  2935313.0  0.421828

# %%
# 0.42 = 42%

# %%
df1["pub_per"] = df1["Public"] / df1["Total"]

# %%
df1
# Out:
#                        State/UT   Private    Public     Total   pub_per
# 0   Andaman and Nicobar Islands       1.0      21.0      22.0  0.954545
# 1                Andhra Pradesh   97863.0   34385.0  132248.0  0.260004
# 2             Arunachal Pradesh       5.0     630.0     635.0  0.992126
# 3                         Assam   14350.0   33553.0   47903.0  0.700436
# 4                         Bihar   11747.0   34814.0   46561.0  0.747707
# 5                    Chandigarh     302.0     509.0     811.0  0.627620
# 6                  Chhattisgarh  411814.0  142123.0  553937.0  0.256569
# 7        Dadra and Nagar Haveli     782.0   10940.0   11722.0  0.933288
# 8                 Daman and Diu     984.0    3343.0    4327.0  0.772591
# 9                           Goa    1033.0     382.0    1415.0  0.269965
# 10                      Gujarat  379379.0   94845.0  474224.0  0.200000
# 11                      Haryana   16341.0   10223.0   26564.0  0.384844
# 12             Himachal Pradesh    2160.0   16461.0   18621.0  0.884002
# 13            Jammu and Kashmir    9707.0    8720.0   18427.0  0.473219
# 14                    Jharkhand  156760.0   24114.0  180874.0  0.133319
# 15                    Karnataka   65502.0  128640.0  194142.0  0.662608
# 16                       Kerala  131557.0  391079.0  522636.0  0.748282
# 17                  Lakshadweep       NaN       NaN       NaN       NaN
# 18               Madhya Pradesh   29314.0   63818.0   93132.0  0.685242
# 19                  Maharashtra  107977.0   31179.0  139156.0  0.224058
# 20                      Manipur     725.0    2412.0    3137.0  0.768887
# 21                    Meghalaya    4836.0    9016.0   13852.0  0.650881
# 22                      Mizoram     441.0   12588.0   13029.0  0.966152
# 23                     Nagaland     325.0     532.0     857.0  0.620770
# 24                   Puducherry       NaN       NaN       NaN       NaN
# 25                       Sikkim      21.0      91.0     112.0  0.812500
# 26                   Tamil Nadu  120473.0  116701.0  237174.0  0.492048
# 27                      Tripura      90.0   16702.0   16792.0  0.994640
# 28                Uttar Pradesh   89987.0   26800.0  116787.0  0.229478
# 29                  Uttarakhand   30472.0   18108.0   48580.0  0.372746
# 30                  West Bengal   12169.0    5467.0   17636.0  0.309991

# %%
df1["pub_per"].mean()
# Out:
# 0.590638596657387

# %%
# 0.59 = 59%

# %% [markdown]
# #The mean of public hospitals on pan india level is 42% whereas mean of all states is 59%.
#
# #Thus public hospitals are more preferable on a state level.

# %% [markdown]
# ## Question 11: Which States/UTs have more than 50000 hospitalisations?

# %%
df1[df1.Total>50000].sort_values(by = "Total", ascending = False)["State/UT"]
# Out:
# 6       Chhattisgarh
# 16            Kerala
# 10           Gujarat
# 26        Tamil Nadu
# 15         Karnataka
# 14         Jharkhand
# 19       Maharashtra
# 1     Andhra Pradesh
# 28     Uttar Pradesh
# 18    Madhya Pradesh
# Name: State/UT, dtype: object

# %% [markdown]
# ## Question 12: Which state reported exactly 1 case of private hospitalisation?

# %%
df1[df1["Private"] == 1]["State/UT"]
# Out:
# 0    Andaman and Nicobar Islands
# Name: State/UT, dtype: object

# %% [markdown]
# ## Question 13: Which State/UT has maximum number of people admitted to public hospitals?

# %%
df1[df1["Public"] == df1["Public"].max()]["State/UT"]
# hosp_copy[hosp_copy['Public']==hosp_copy['Public'].max()]['State/UT']
# Out:
# 16    Kerala
# Name: State/UT, dtype: object

# %% [markdown]
# ## Question 14: Which state among Tripura and Gujarat witnessed more hospitalisations?
# (in absolute numbers)

# %%
df[df["State/UT"] == "Tripura"]
# Out:
#    State/UT  Private   Public    Total  pub_per
# 27  Tripura     90.0  16702.0  16792.0  0.99464

# %%
df[df["State/UT"] == "Gujarat"]
# Out:
#    State/UT   Private   Public     Total  pub_per
# 10  Gujarat  379379.0  94845.0  474224.0      0.2

# %% [markdown]
# ## Question 15: Are there any extreme values/ outliers present in this data set? Do these
# values impact the analysis?

# %%
#Plotting Boxplots for Outlier visual
data_plot=df1[df1.dtypes[df1.dtypes!='object'].index]
fig=plt.figure(figsize=(12,7))
for i in range(0,len(data_plot.columns)):
   ax=fig.add_subplot(2,2,i+1)
   sns.boxplot(data_plot[data_plot.columns[i]])
   ax.set_title(data_plot.columns[i],color='Blue')
plt.tight_layout()
