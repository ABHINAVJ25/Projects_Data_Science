# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline
sns.set_palette("deep")
from warnings import filterwarnings
filterwarnings("ignore")

# %%
uber_drives = pd.read_csv("uberdrives.csv")

# %% [markdown]
# ## Q1. Show the last 10 records of the dataset. (2 point)

# %%
uber_drives.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Karachi     2.8  Errand/Supplies
# 1146           Karachi     2.9  Errand/Supplies
# 1147           Karachi     4.6  Errand/Supplies
# ...

# %% [markdown]
# ##  Q2. Show the first 10 records of the dataset. (2 points)

# %%
uber_drives.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %% [markdown]
# ## Q3.Show the dimension(number of rows and columns) of the dataset.

# %%
uber_drives
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
print(uber_drives.shape)
print("No of rows are :", uber_drives.shape[0])
print("No of columns are :", uber_drives.shape[1])
# Out:
# (1155, 7)
# No of rows are : 1155
# No of columns are : 7

# %% [markdown]
# ## Q4.Show the size (Total number of elements) of the dataset. (2 points)

# %%
uber_drives.size
# Out:
# 8085

# %% [markdown]
# ## Q5. Display the information about all the variables of the data set. What can you infer from the output?(1 +2 points)
# Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
uber_drives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## Q6.Check for missing values. (2 points)
#    Note: Output should contain only one boolean value

# %%
uber_drives.isnull().sum().sum()
# Out:
# 502

# %%
uber_drives.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [1155 rows x 7 columns]

# %%
uber_drives.isna().values.any()
# Out:
# True

# %% [markdown]
# ## Q7. How many missing values are present in the entire dataset?

# %%
uber_drives.isnull().sum().sum()
# Out:
# 502

# %%
uber_drives.isna().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False,  True],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %% [markdown]
# ## Q8. Get the summary of the original data. (2 points).
# Hint: Summary includes- Count,Mean, Std, Min, 25%,50%,75% and max

# %%
uber_drives.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# ## Q9. Drop the missing values and store the data in a new dataframe (name it"df") (2-points)
# Note: Dataframe "df" will not contain any missing value

# %%
df = uber_drives.dropna()

# %%
# df.isnull().sum().sum()
df.isnull().values.any()
# Out:
# False

# %%
df.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# 5  West Palm Beach     4.3   Meal/Entertain

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Q10. Check the information of the dataframe(df). (1 points)
# Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Q11. Get the unique start locations. (2 points)
# Note: This question is based on the dataframe with no 'NA' values

# %%
df["START*"].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Lake Wellingborough',
#        'Fayetteville Street', 'Raleigh', 'Whitebridge', 'Hazelwood',
#        'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill', 'Northwoods',
#        'Edgehill Farms', 'Eastgate', 'East Elmhurst', 'Long Island City',
#        'Katunayaka', 'Colombo', 'Nugegoda', 'Unknown Location',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Preston',
#        'Heritage Pines', 'Tanglewood', 'Waverly Place', 'Wayne Ridge',
#        'Westpark Place', 'East Austin', 'The Drag', 'South Congress',
#        'Georgian Acres', 'North Austin', 'West University', 'Austin',
# ...

# %% [markdown]
# ## Q12. What is the total number of unique start locations? (2 points)
# Note: Use the original dataframe without dropping 'NA' values

# %%
df["START*"].nunique()
# Out:
# 131

# %%
uber_drives["START*"].nunique()
# Out:
# 176

# %% [markdown]
# ## Q13. What is the total number of unique stop locations. (2 points)
# Note: Use the original dataframe without dropping 'NA' values.

# %%
df["STOP*"].nunique()
# Out:
# 137

# %%
uber_drives["STOP*"].nunique()
# Out:
# 187

# %% [markdown]
# ## Q14. Display all Uber trips that has the starting point as San Francisco. (2 points)
# Note: Use the original dataframe without dropping the 'NA' values.

# %%
uber_drives["START*"] == "San Francisco"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1150    False
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# Name: START*, Length: 1155, dtype: bool

# %%
uber_drives.loc[uber_drives["START*"] == "San Francisco"]
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (2 points)
# Note: Use the original dataframe without dropping the 'NA' values.
#
# Hint:Popular means the place that is visited the most

# %%
uber_drives.sort_values('START*', ascending = False).head(50)
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*  \
# 870  10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
# 648  08-11-2016 12:53  08-11-2016 13:00  Business    Whitebridge
# 72   02-04-2016 18:04  02-04-2016 18:31  Business    Whitebridge
# 889  11-01-2016 17:35  11-01-2016 17:42  Business    Whitebridge
# 459   6/24/2016 10:41   6/24/2016 10:57  Business    Whitebridge
# 653  08-12-2016 18:49  08-12-2016 18:52  Business    Whitebridge
# 890  11-01-2016 19:14  11-01-2016 19:20  Business    Whitebridge
# 891  11-01-2016 19:59  11-01-2016 20:12  Business    Whitebridge
# 892  11-01-2016 20:41  11-01-2016 20:55  Business    Whitebridge
# 64   02-02-2016 13:04  02-02-2016 13:23  Business    Whitebridge
# 577   7/21/2016 17:17   7/21/2016 17:23  Business    Whitebridge
# 898  11-03-2016 11:28  11-03-2016 11:34  Business    Whitebridge
# 900  11-03-2016 13:42  11-03-2016 13:47  Business    Whitebridge
# ...

# %%
uber_drives["START*"].value_counts()
# Out:
# Cary                 201
# Unknown Location     148
# Morrisville           85
# Whitebridge           68
# Islamabad             57
#                     ...
# Ridgeland              1
# Daytona Beach          1
# Sky Lake               1
# Sand Lake Commons      1
# Gampaha                1
# Name: START*, Length: 176, dtype: int64

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (2 points)
# Note: Use the original dataframe without dropping the 'NA' values.
#
# Hint: Popular means the place that is visited the most.

# %%
uber_drives.sort_values("STOP*", ascending = False).head(50)
# Out:
#           START_DATE*         END_DATE* CATEGORY*          START*  \
# 869  10/28/2016 15:53  10/28/2016 17:59  Business            Cary
# 64   02-02-2016 13:04  02-02-2016 13:23  Business     Whitebridge
# 382   5/23/2016 21:09   5/23/2016 21:21  Business    Savon Height
# 899  11-03-2016 12:43  11-03-2016 12:49  Business       Hazelwood
# 428  06-11-2016 17:50  06-11-2016 17:56  Business  Westpark Place
# 654  08-12-2016 18:56  08-12-2016 19:05  Business  Westpark Place
# 433  06-12-2016 21:58  06-12-2016 22:19  Business         Parkway
# 161   2/25/2016 18:22   2/25/2016 18:39  Business      Tanglewood
# 263   3/22/2016 19:12   3/22/2016 19:25  Personal     Whitebridge
# 901  11-03-2016 14:13  11-03-2016 14:26  Business  Westpark Place
# 63   02-01-2016 12:56  02-01-2016 13:07  Business      Northwoods
# 650  08-11-2016 13:32  08-11-2016 13:42  Business  Edgehill Farms
# 512  07-04-2016 18:23  07-04-2016 18:49  Business     Summerwinds
# ...

# %%
uber_drives["STOP*"].value_counts()
# Out:
# Cary                 203
# Unknown Location     149
# Morrisville           84
# Whitebridge           65
# Islamabad             58
#                     ...
# Daytona Beach          1
# Sand Lake Commons      1
# Sky Lake               1
# Vista East             1
# Ilukwatta              1
# Name: STOP*, Length: 187, dtype: int64

# %% [markdown]
# ## Q17. What is the most frequent route taken by Uber drivers. (3 points)
# Note: This question is based on the new dataframe with no 'na' values.
#
# Hint-Print the most frequent route taken by Uber drivers (Route= combination of START & END points present in the dataset.

# %%
Route = df['START*'].astype(str) + df['STOP*']

# %%
Route.sort_values(ascending = False).head(50)
# Out:
# 870                  Winston SalemAsheville
# 64            WhitebridgeWilliamsburg Manor
# 516                  WhitebridgeWhitebridge
# 892                  WhitebridgeWhitebridge
# 343               WhitebridgeWestpark Place
# 42                WhitebridgeWestpark Place
# 348               WhitebridgeWestpark Place
# 196                  WhitebridgeWayne Ridge
# 321                  WhitebridgeWayne Ridge
# 300                  WhitebridgeWayne Ridge
# 176                  WhitebridgeWayne Ridge
# 169                WhitebridgeWaverly Place
# 459                WhitebridgeWaverly Place
# 341                WhitebridgeWaverly Place
# 204                WhitebridgeWaverly Place
# 160                   WhitebridgeTanglewood
# 327                   WhitebridgeTanglewood
# 345                   WhitebridgeTanglewood
# 511                  WhitebridgeSummerwinds
# 569                   WhitebridgeStonewater
# 401                 WhitebridgeSavon Height
# ...

# %%
Route.value_counts()
# Out:
# CaryMorrisville                     52
# MorrisvilleCary                     51
# CaryCary                            44
# Unknown LocationUnknown Location    30
# CaryDurham                          30
#                                     ..
# GalvestonHouston                     1
# MidtownWashington Avenue             1
# Washington AvenueMidtown             1
# Briar MeadowMidtown                  1
# GampahaIlukwatta                     1
# Length: 239, dtype: int64

# %%
df.groupby(["START*", "STOP*"]).size().sort_values(ascending = False).head(10)
# Out:
# START*            STOP*
# Cary              Morrisville         52
# Morrisville       Cary                51
# Cary              Cary                44
# Unknown Location  Unknown Location    30
# Cary              Durham              30
# Durham            Cary                29
# Karachi           Karachi             20
# Cary              Raleigh             17
# Lahore            Lahore              16
# Raleigh           Cary                15
# dtype: int64

# %%
df.groupby(["START*", "STOP*"]).size().sort_values(ascending = False).head(1)
# Out:
# START*  STOP*
# Cary    Morrisville    52
# dtype: int64

# %% [markdown]
# ## Q18. Display all types of purposes for the trip in an array. (2 points)
# Note: This question is based on the new dataframe with no 'NA' values.

# %%
z = list(df["PURPOSE*"])

# %%
z
# Out:
# ['Meal/Entertain',
#  'Errand/Supplies',
#  'Meeting',
#  'Customer Visit',
#  'Meal/Entertain',
#  'Meeting',
#  'Meeting',
#  'Meeting',
#  'Customer Visit',
#  'Meeting',
#  'Meeting',
#  'Meeting',
#  'Temporary Site',
#  'Errand/Supplies',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Errand/Supplies',
#  'Customer Visit',
#  'Errand/Supplies',
#  'Meeting',
#  'Meeting',
#  'Meeting',
#  'Customer Visit',
#  'Errand/Supplies',
#  'Errand/Supplies',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Temporary Site',
#  'Meeting',
#  'Meeting',
#  'Customer Visit',
#  'Errand/Supplies',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Meal/Entertain',
#  'Errand/Supplies',
#  'Errand/Supplies',
#  'Errand/Supplies',
#  'Errand/Supplies',
#  'Meeting',
#  'Customer Visit',
#  'Customer Visit',
#  'Customer Visit',
#  'Customer Visit',
#  'Temporary Site',
#  'Meeting',
#  'Meeting',
#  'Customer Visit',
# ...

# %%
print(np.array(df["PURPOSE*"].unique()))
# Out:
# ['Meal/Entertain' 'Errand/Supplies' 'Meeting' 'Customer Visit'
#  'Temporary Site' 'Between Offices' 'Charity ($)' 'Commute' 'Moving'
#  'Airport/Travel']

# %% [markdown]
# ## Q19. Plot a bar graph of Purpose vs Miles(Distance). What can you infer from the plot(2 +2 points)
# Note: Use the original dataframe without dropping the 'NA' values.
#
# Hint:You have to plot total/sum miles per purpose

# %%
sns.barplot(data = uber_drives, y = "PURPOSE*", x = "MILES*");

# %%
df1 = pd.DataFrame(uber_drives["MILES*"]).groupby(uber_drives["PURPOSE*"]).sum()
df1.plot(kind = "bar")
plt.show()

# %% [markdown]
# ## Q20. Display a dataframe of Purpose and the total distance travelled for that particular Purpose. (3 points)
# Note: Use the original dataframe without dropping "NA" values.

# %%
sns.barplot(data = uber_drives, y = "PURPOSE*", x = "MILES*")
# Out:
# <Axes: xlabel='MILES*', ylabel='PURPOSE*'>

# %%
uber_drives.groupby("PURPOSE*").sum()
# Out:
#                  MILES*
# PURPOSE*
# Airport/Travel     16.5
# Between Offices   197.0
# Charity ($)        15.1
# Commute           180.2
# Customer Visit   2089.5
# Errand/Supplies   508.0
# Meal/Entertain    911.7
# Meeting          2851.3
# Moving             18.2
# Temporary Site    523.7

# %% [markdown]
# ## Q21. Generate a plot showing count of trips vs category of trips. What can you infer from the plot (2 +1 points)
# Note: Use the original dataframe without dropping the 'NA' values.

# %%
uber_drives["CATEGORY*"].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
uber_drives["CATEGORY*"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Q22. What percentage of Miles were clocked under Business Category and what percentage of Miles were clocked under Personal Category ? (3 points)
# Note:Use the original dataframe without dropping the 'NA' values.

# %%
df_1 = uber_drives["CATEGORY*"] == "Business"

# %%
df_1
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1150    True
# 1151    True
# 1152    True
# 1153    True
# 1154    True
# Name: CATEGORY*, Length: 1155, dtype: bool

# %%
df_2 = uber_drives["CATEGORY*"] == "Personal"
df_2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1150    False
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# Name: CATEGORY*, Length: 1155, dtype: bool

# %%
df.tail(20)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1135  12/29/2016 12:25  12/29/2016 12:33  Business           Karachi
# 1136  12/29/2016 13:17  12/29/2016 13:24  Business           Karachi
# 1137  12/29/2016 13:56  12/29/2016 14:11  Business           Karachi
# 1138  12/29/2016 14:42  12/29/2016 14:58  Business           Karachi
# 1139  12/29/2016 15:05  12/29/2016 15:16  Business           Karachi
# 1140  12/29/2016 18:59  12/29/2016 19:14  Business           Karachi
# 1141  12/29/2016 19:50  12/29/2016 20:10  Business  Unknown Location
# 1142  12/29/2016 20:15  12/29/2016 20:45  Business           Karachi
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# ...

# %%
uber_drives.groupby("CATEGORY*").sum()
# Out:
#             MILES*
# CATEGORY*
# Business   11487.0
# Personal     717.7

# %%
uber_drives.groupby("CATEGORY*").sum() / uber_drives["MILES*"].sum()
# Out:
#              MILES*
# CATEGORY*
# Business   0.941195
# Personal   0.058805

# %%
uber_drives.groupby("CATEGORY*").sum() / uber_drives['MILES*'].sum()*100
# Out:
#               MILES*
# CATEGORY*
# Business   94.119479
# Personal    5.880521

# %% [markdown]
#  # DONE WITH THE UBER_DRIVE_PROJECT
